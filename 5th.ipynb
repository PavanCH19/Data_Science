# %% [markdown]
# Develop a program to implement k-Nearest Neighbour algorithm to classify the randomly generated 100
# values of x in the range of [0,1]. Perform the following based on dataset generated.
# a. Label the first 50 points {x1,……,x50} as follows: if (xi ≤ 0.5), then xi ∊ Class1, else xi ∊ Class1
# b. Classify the remaining points, x51,……,x100 using KNN. Perform this for k=1,2,3,4,5,20,30

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.neighbors import KNeighborsClassifier

# %%
data = np.random.rand(100)

# %%
train_labels = ["class 1" if x <= 0.5 else "class 2" for x in data[:50]]

# %%
train_data = data[:50].reshape(-1,1)
test_data = data[50:].reshape(-1,1)

# %%
k_values = [1,2,3,5,20,30]

# %%
for k in k_values:
    print(f"\nprediction for k : {k}")
    
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(train_data,train_labels)
    predicted_labels = knn.predict(test_data)

    for i in range (len(test_data)):
        print(f"the value {test_data[i][0]:.2f} is predicted as {predicted_labels[i]}")

    label = train_labels + list(predicted_labels)
    Type = ["train"] * len(train_data) + ["test"] * len(test_data)
    y = [0] * len(train_data) + [1] * len(test_data)

    df = pd.DataFrame({
        'value' : data,
        'label' : label,
        'Type' : Type,
        'y' : y
    })

    plt.figure(figsize=(10,8))
    sns.scatterplot(df, x="value", y='y', hue='label', style='Type', s=100)
    plt.title("knn-classifier")
    plt.tight_layout()
    plt.grid(True)
    plt.show()
# Out:
# prediction for k : 1
# the value 0.23 is predicted as class 1
# the value 0.10 is predicted as class 1
# the value 0.87 is predicted as class 2
# the value 0.05 is predicted as class 1
# the value 0.15 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.46 is predicted as class 1
# the value 0.81 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.30 is predicted as class 1
# the value 0.42 is predicted as class 1
# the value 0.89 is predicted as class 2
# the value 0.57 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.34 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.06 is predicted as class 1
# the value 0.96 is predicted as class 2
# the value 0.71 is predicted as class 2
# the value 0.08 is predicted as class 1
# the value 0.93 is predicted as class 2
# the value 0.74 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.04 is predicted as class 1
# the value 0.91 is predicted as class 2
# the value 0.81 is predicted as class 2
# the value 0.94 is predicted as class 2
# the value 0.75 is predicted as class 2
# the value 0.40 is predicted as class 1
# the value 0.60 is predicted as class 2
# the value 0.50 is predicted as class 1
# the value 0.31 is predicted as class 1
# the value 0.83 is predicted as class 2
# the value 0.41 is predicted as class 1
# the value 0.56 is predicted as class 2
# the value 0.62 is predicted as class 2
# the value 0.39 is predicted as class 1
# the value 0.98 is predicted as class 2
# the value 0.77 is predicted as class 2
# the value 0.60 is predicted as class 2
# the value 0.88 is predicted as class 2
# the value 0.37 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.22 is predicted as class 1
# the value 0.47 is predicted as class 1
# the value 0.34 is predicted as class 1
# the value 0.80 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.45 is predicted as class 1
# prediction for k : 2
# the value 0.23 is predicted as class 1
# the value 0.10 is predicted as class 1
# the value 0.87 is predicted as class 2
# the value 0.05 is predicted as class 1
# the value 0.15 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.46 is predicted as class 1
# the value 0.81 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.30 is predicted as class 1
# the value 0.42 is predicted as class 1
# the value 0.89 is predicted as class 2
# the value 0.57 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.34 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.06 is predicted as class 1
# the value 0.96 is predicted as class 2
# the value 0.71 is predicted as class 2
# the value 0.08 is predicted as class 1
# the value 0.93 is predicted as class 2
# the value 0.74 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.04 is predicted as class 1
# the value 0.91 is predicted as class 2
# the value 0.81 is predicted as class 2
# the value 0.94 is predicted as class 2
# the value 0.75 is predicted as class 2
# the value 0.40 is predicted as class 1
# the value 0.60 is predicted as class 2
# the value 0.50 is predicted as class 1
# the value 0.31 is predicted as class 1
# the value 0.83 is predicted as class 2
# the value 0.41 is predicted as class 1
# the value 0.56 is predicted as class 2
# the value 0.62 is predicted as class 2
# the value 0.39 is predicted as class 1
# the value 0.98 is predicted as class 2
# the value 0.77 is predicted as class 2
# the value 0.60 is predicted as class 2
# the value 0.88 is predicted as class 2
# the value 0.37 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.22 is predicted as class 1
# the value 0.47 is predicted as class 1
# the value 0.34 is predicted as class 1
# the value 0.80 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.45 is predicted as class 1
# prediction for k : 3
# the value 0.23 is predicted as class 1
# the value 0.10 is predicted as class 1
# the value 0.87 is predicted as class 2
# the value 0.05 is predicted as class 1
# the value 0.15 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.46 is predicted as class 1
# the value 0.81 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.30 is predicted as class 1
# the value 0.42 is predicted as class 1
# the value 0.89 is predicted as class 2
# the value 0.57 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.34 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.06 is predicted as class 1
# the value 0.96 is predicted as class 2
# the value 0.71 is predicted as class 2
# the value 0.08 is predicted as class 1
# the value 0.93 is predicted as class 2
# the value 0.74 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.04 is predicted as class 1
# the value 0.91 is predicted as class 2
# the value 0.81 is predicted as class 2
# the value 0.94 is predicted as class 2
# the value 0.75 is predicted as class 2
# the value 0.40 is predicted as class 1
# the value 0.60 is predicted as class 2
# the value 0.50 is predicted as class 2
# the value 0.31 is predicted as class 1
# the value 0.83 is predicted as class 2
# the value 0.41 is predicted as class 1
# the value 0.56 is predicted as class 2
# the value 0.62 is predicted as class 2
# the value 0.39 is predicted as class 1
# the value 0.98 is predicted as class 2
# the value 0.77 is predicted as class 2
# the value 0.60 is predicted as class 2
# the value 0.88 is predicted as class 2
# the value 0.37 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.22 is predicted as class 1
# the value 0.47 is predicted as class 1
# the value 0.34 is predicted as class 1
# the value 0.80 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.45 is predicted as class 1
# prediction for k : 5
# the value 0.23 is predicted as class 1
# the value 0.10 is predicted as class 1
# the value 0.87 is predicted as class 2
# the value 0.05 is predicted as class 1
# the value 0.15 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.46 is predicted as class 1
# the value 0.81 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.30 is predicted as class 1
# the value 0.42 is predicted as class 1
# the value 0.89 is predicted as class 2
# the value 0.57 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.34 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.06 is predicted as class 1
# the value 0.96 is predicted as class 2
# the value 0.71 is predicted as class 2
# the value 0.08 is predicted as class 1
# the value 0.93 is predicted as class 2
# the value 0.74 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.04 is predicted as class 1
# the value 0.91 is predicted as class 2
# the value 0.81 is predicted as class 2
# the value 0.94 is predicted as class 2
# the value 0.75 is predicted as class 2
# the value 0.40 is predicted as class 1
# the value 0.60 is predicted as class 2
# the value 0.50 is predicted as class 2
# the value 0.31 is predicted as class 1
# the value 0.83 is predicted as class 2
# the value 0.41 is predicted as class 1
# the value 0.56 is predicted as class 2
# the value 0.62 is predicted as class 2
# the value 0.39 is predicted as class 1
# the value 0.98 is predicted as class 2
# the value 0.77 is predicted as class 2
# the value 0.60 is predicted as class 2
# the value 0.88 is predicted as class 2
# the value 0.37 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.22 is predicted as class 1
# the value 0.47 is predicted as class 1
# the value 0.34 is predicted as class 1
# the value 0.80 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.45 is predicted as class 1
# prediction for k : 20
# the value 0.23 is predicted as class 1
# the value 0.10 is predicted as class 1
# the value 0.87 is predicted as class 2
# the value 0.05 is predicted as class 1
# the value 0.15 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.46 is predicted as class 2
# the value 0.81 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.30 is predicted as class 1
# the value 0.42 is predicted as class 1
# the value 0.89 is predicted as class 2
# the value 0.57 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.34 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.06 is predicted as class 1
# the value 0.96 is predicted as class 2
# the value 0.71 is predicted as class 2
# the value 0.08 is predicted as class 1
# the value 0.93 is predicted as class 2
# the value 0.74 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.04 is predicted as class 1
# the value 0.91 is predicted as class 2
# the value 0.81 is predicted as class 2
# the value 0.94 is predicted as class 2
# the value 0.75 is predicted as class 2
# the value 0.40 is predicted as class 1
# the value 0.60 is predicted as class 2
# the value 0.50 is predicted as class 2
# the value 0.31 is predicted as class 1
# the value 0.83 is predicted as class 2
# the value 0.41 is predicted as class 1
# the value 0.56 is predicted as class 2
# the value 0.62 is predicted as class 2
# the value 0.39 is predicted as class 1
# the value 0.98 is predicted as class 2
# the value 0.77 is predicted as class 2
# the value 0.60 is predicted as class 2
# the value 0.88 is predicted as class 2
# the value 0.37 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.22 is predicted as class 1
# the value 0.47 is predicted as class 2
# the value 0.34 is predicted as class 1
# the value 0.80 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.45 is predicted as class 1
# prediction for k : 30
# the value 0.23 is predicted as class 1
# the value 0.10 is predicted as class 1
# the value 0.87 is predicted as class 2
# the value 0.05 is predicted as class 1
# the value 0.15 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.46 is predicted as class 2
# the value 0.81 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.30 is predicted as class 1
# the value 0.42 is predicted as class 2
# the value 0.89 is predicted as class 2
# the value 0.57 is predicted as class 2
# the value 0.64 is predicted as class 2
# the value 0.34 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.03 is predicted as class 1
# the value 0.06 is predicted as class 1
# the value 0.96 is predicted as class 2
# the value 0.71 is predicted as class 2
# the value 0.08 is predicted as class 1
# the value 0.93 is predicted as class 2
# the value 0.74 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.04 is predicted as class 1
# the value 0.91 is predicted as class 2
# the value 0.81 is predicted as class 2
# the value 0.94 is predicted as class 2
# the value 0.75 is predicted as class 2
# the value 0.40 is predicted as class 1
# the value 0.60 is predicted as class 2
# the value 0.50 is predicted as class 2
# the value 0.31 is predicted as class 1
# the value 0.83 is predicted as class 2
# the value 0.41 is predicted as class 2
# the value 0.56 is predicted as class 2
# the value 0.62 is predicted as class 2
# the value 0.39 is predicted as class 1
# the value 0.98 is predicted as class 2
# the value 0.77 is predicted as class 2
# the value 0.60 is predicted as class 2
# the value 0.88 is predicted as class 2
# the value 0.37 is predicted as class 1
# the value 0.33 is predicted as class 1
# the value 0.22 is predicted as class 1
# the value 0.47 is predicted as class 2
# the value 0.34 is predicted as class 1
# the value 0.80 is predicted as class 2
# the value 0.84 is predicted as class 2
# the value 0.45 is predicted as class 2
