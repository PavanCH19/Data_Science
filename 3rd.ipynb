# %% [markdown]
# Develop a program to implement Principal Component Analysis (PCA) for reducing the dimensionality of
# the Iris dataset from 4 features to 2

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# %%
data = load_iris(as_frame=True)
df = data.frame
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(df[data.feature_names])
reduced_data
# Out:
# array([[-2.68412563,  0.31939725],
#        [-2.71414169, -0.17700123],
#        [-2.88899057, -0.14494943],
#        [-2.74534286, -0.31829898],
#        [-2.72871654,  0.32675451],
#        [-2.28085963,  0.74133045],
#        [-2.82053775, -0.08946138],
#        [-2.62614497,  0.16338496],
#        [-2.88638273, -0.57831175],
#        [-2.6727558 , -0.11377425],
#        [-2.50694709,  0.6450689 ],
#        [-2.61275523,  0.01472994],
#        [-2.78610927, -0.235112  ],
#        [-3.22380374, -0.51139459],
#        [-2.64475039,  1.17876464],
#        [-2.38603903,  1.33806233],
#        [-2.62352788,  0.81067951],
#        [-2.64829671,  0.31184914],
#        [-2.19982032,  0.87283904],
#        [-2.5879864 ,  0.51356031],
#        [-2.31025622,  0.39134594],
#        [-2.54370523,  0.43299606],
#        [-3.21593942,  0.13346807],
#        [-2.30273318,  0.09870885],
#        [-2.35575405, -0.03728186],
#        [-2.50666891, -0.14601688],
#        [-2.46882007,  0.13095149],
# ...

# %%
reduced_df = pd.DataFrame(reduced_data, columns=['pc1', 'pc2'])
reduced_df["target"] = data.target
reduced_df
# Out:
#           pc1       pc2  target
# 0   -2.684126  0.319397       0
# 1   -2.714142 -0.177001       0
# 2   -2.888991 -0.144949       0
# 3   -2.745343 -0.318299       0
# 4   -2.728717  0.326755       0
# ..        ...       ...     ...
# 145  1.944110  0.187532       2
# 146  1.527167 -0.375317       2
# 147  1.764346  0.078859       2
# 148  1.900942  0.116628       2
# 149  1.390189 -0.282661       2
#
# [150 rows x 3 columns]

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(reduced_df, x="pc1", y="pc2", hue="target", palette="Set1")
plt.title("scatterplot for reduced iris data")
plt.show()
